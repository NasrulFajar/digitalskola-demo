# %%
import urllib.request, json, timeit, pandas as pd

# %%
shopee_url = "https://shopee.co.id/api/v4/search/search_items?by=relevancy&limit=60&match_id=1028154&newest=0&order=desc&page_type=collection&scenario=PAGE_COLLECTION_SEARCH&version=2"
print(shopee_url)
with urllib.request.urlopen(shopee_url) as url:
    data_shopee = json.loads(url.read().decode())
# Out:
# https://shopee.co.id/api/v4/search/search_items?by=relevancy&limit=60&match_id=1028154&newest=0&order=desc&page_type=collection&scenario=PAGE_COLLECTION_SEARCH&version=2

# %%
data_shopee
# Out:
# {'bff_meta': None,
#  'error': None,
#  'error_msg': None,
#  'reserved_keyword': None,
#  'suggestion_algorithm': None,
#  'algorithm': 'eyJzZWFyY2giOiIifQ==',
#  'total_count': 94,
#  'nomore': False,
#  'items': [{'item_basic': {'itemid': 9033781513,
#     'shopid': 318835972,
#     'name': 'Silverqueen Almond 62 g',
#     'label_ids': [1002164,
#      1006221,
#      1006732,
#      1008411,
#      1008448,
#      1011185,
#      1011707,
#      1011688,
#      1011693,
#      1011995,
#      1011962,
#      1012310,
#      1012295,
#      1012616,
#      1012619,
#      1012746,
#      1000031,
#      1000006,
#      1004684,
#      1001025,
#      32,
#      1009533,
#      1009537,
#      1009454,
#      1010928,
#      1011621,
#      1011718,
#      1012050,
#      1011751,
#      1011752,
#      1011712,
#      1011961,
#      1012435,
#      1011749,
#      1012446,
#      1012218,
#      1012791],
#     'image': '372ec1008b4c8baffba7acbb25e6dbd8',
#     'images': ['372ec1008b4c8baffba7acbb25e6dbd8',
#      '2b831aedbb63d75c8123ceae3e8bf543',
#      'e4f4aa78ac8a95b185dbe2eb486f174e'],
#     'currency': 'IDR',
#     'stock': 199,
#     'status': 1,
#     'ctime': 1617012805,
#     'sold': 101,
#     'historical_sold': 1465,
#     'liked': False,
#     'liked_count': 314,
#     'view_count': 14366,
#     'catid': 100629,
#     'brand': 'Silverqueen ',
#     'cmt_count': 686,
#     'flag': 268632066,
#     'cb_option': 0,
#     'item_status': 'normal',
#     'price': 1550000000,
#     'price_min': 1550000000,
#     'price_max': 1550000000,
#     'price_min_before_discount': 1560000000,
#     'price_max_before_discount': 1560000000,
#     'hidden_price_display': None,
#     'price_before_discount': 1560000000,
#     'has_lowest_price_guarantee': False,
#     'show_discount': 1,
#     'raw_discount': 1,
#     'discount': '1%',
#     'is_category_failed': False,
#     'size_chart': None,
#     'video_info_list': None,
#     'tier_variations': [{'name': '',
#       'options': [''],
#       'images': None,
#       'properties': [],
#       'type': 0}],
#     'item_rating': {'rating_star': 4.819241982507289,
#      'rating_count': [686, 5, 4, 8, 76, 593],
#      'rcount_with_context': 290,
#      'rcount_with_image': 259},
#     'item_type': 0,
#     'reference_item_id': '',
#     'transparent_background_image': '63e0f552d19481cc81f6a723f4075f13',
#     'is_adult': False,
#     'badge_icon_type': 5,
#     'shopee_verified': False,
#     'is_official_shop': True,
#     'show_official_shop_label': True,
#     'show_shopee_verified_label': False,
#     'show_official_shop_label_in_title': True,
#     'is_cc_installment_payment_eligible': False,
#     'is_non_cc_installment_payment_eligible': False,
#     'coin_earn_label': None,
#     'show_free_shipping': True,
#     'preview_info': None,
#     'coin_info': None,
#     'exclusive_price_info': None,
#     'bundle_deal_id': 0,
#     'can_use_bundle_deal': False,
#     'bundle_deal_info': None,
#     'is_group_buy_item': None,
#     'has_group_buy_stock': None,
#     'group_buy_info': None,
#     'welcome_package_type': 0,
#     'welcome_package_info': None,
#     'add_on_deal_info': None,
#     'can_use_wholesale': False,
#     'is_preferred_plus_seller': False,
#     'shop_location': 'KOTA BEKASI',
#     'has_model_with_available_shopee_stock': True,
#     'voucher_info': None,
#     'can_use_cod': True,
#     'is_on_flash_sale': False,
#     'spl_installment_tenure': None,
#     'is_live_streaming_price': None,
#     'is_mart': False,
#     'pack_size': None,
#     'deep_discount_skin': None},
#    'adsid': None,
#    'campaignid': None,
#    'distance': None,
#    'match_type': None,
#    'ads_keyword': None,
#    'deduction_info': None,
#    'collection_id': 1028154,
#    'display_name': '',
#    'campaign_stock': 0,
#    'json_data': None,
#    'tracking_info': None,
#    'itemid': 9033781513,
#    'shopid': 318835972,
#    'algo_image': None,
#    'fe_flags': None,
#    'item_type': 1,
#    'foody_item': None,
#    'search_item_tracking': '{"is_ads":false,"groupid":0,"fe_flags":"{}","item_type":1,"biz_json":"","merge_rank":0,"shuffle_rank":0}',
#    'bff_item_tracking': '{"label_ids":[1002164,1006221,1006732,1008411,1008448,1011185,1011707,1011688,1011693,1011995,1011962,1012310,1012295,1012616,1012619,1012746,1000031,1000006,1004684,1001025,32,1009533,1009537,1009454,1010928,1011621,1011718,1012050,1011751,1011752,1011712,1011961,1012435,1011749,1012446,1012218,1012791],"is_on_flash_sale":false,"is_liked":false,"with_video":false,"is_dp_mirror_sku":false,"image_position":null}',
#    'personalized_labels': None,
#    'biz_json': None},
#   {'item_basic': {'itemid': 12570400933,
#     'shopid': 194992662,
#     'name': 'WoCA Chocolate Special Valentine Limited Edition',
#     'label_ids': [1000167,
#      1000895,
#      1001176,
#      1001346,
#      1001350,
#      1001657,
#      1001620,
#      1001627,
#      1001642,
#      1002688,
#      1005617,
#      1003454,
#      1005775,
#      1003455,
#      1002164,
#      1006732,
#      1006735,
#      1006761,
#      1011688,
#      1011703,
#      1011707,
#      1011693,
#      1011995,
#      1011962,
#      1012445,
#      1012436,
#      1011689,
#      1011691,
#      1011705,
#      1011993,
#      1012616,
#      1012619,
#      1012746,
#      1000031,
#      1012435,
#      1011712,
#      1011718,
#      1011752,
#      1012446],
#     'image': '133e903115ac9fb0d2439b8c689dd6d1',
#     'images': ['133e903115ac9fb0d2439b8c689dd6d1',
#      '3fb9633ee96fedb0794048e090dafb8d',
#      'f181c64c9dc10684d9c0485550cdf847',
#      '8d36619ec144e20fa9fd8e1ca372f40d',
#      'b730303fc99b356065aee517ee7a9dba',
#      'ebe258df5793f6bb1727b125feec0df9',
#      'a59a9920e03fbf923c9913abe756dbc8',
#      '841e6af2e79babb8c98d2f8ea4844e23'],
#     'currency': 'IDR',
#     'stock': 1,
#     'status': 1,
#     'ctime': 1642227355,
#     'sold': 59,
#     'historical_sold': 41,
#     'liked': False,
#     'liked_count': 57,
#     'view_count': 4923,
#     'catid': 100629,
#     'brand': None,
#     'cmt_count': 18,
#     'flag': 0,
#     'cb_option': 0,
#     'item_status': 'normal',
#     'price': 6999900000,
#     'price_min': 6999900000,
#     'price_max': 6999900000,
#     'price_min_before_discount': 12000000000,
#     'price_max_before_discount': 12000000000,
#     'hidden_price_display': None,
#     'price_before_discount': 12000000000,
#     'has_lowest_price_guarantee': False,
#     'show_discount': 42,
#     'raw_discount': 42,
#     'discount': '42%',
#     'is_category_failed': False,
#     'size_chart': None,
#     'video_info_list': None,
#     'tier_variations': [{'name': 'Pilihan Paket',
#       'options': ['Valentine A', 'Valentine B'],
#       'images': ['7d547fb96289838e6f629f0dd3540132',
#        '523b4ee5b61c908c1936bc0b473a4d9b'],
#       'properties': [],
#       'type': 0}],
#     'item_rating': {'rating_star': 4.944444444444445,
#      'rating_count': [18, 0, 0, 0, 1, 17],
#      'rcount_with_context': 3,
#      'rcount_with_image': 2},
#     'item_type': 0,
#     'reference_item_id': '',
#     'transparent_background_image': '32cb33c178d8dcd6263fcd2f222d2cee',
#     'is_adult': False,
#     'badge_icon_type': 0,
#     'shopee_verified': False,
#     'is_official_shop': True,
#     'show_official_shop_label': True,
#     'show_shopee_verified_label': False,
#     'show_official_shop_label_in_title': True,
#     'is_cc_installment_payment_eligible': False,
#     'is_non_cc_installment_payment_eligible': False,
#     'coin_earn_label': None,
#     'show_free_shipping': False,
#     'preview_info': None,
#     'coin_info': None,
#     'exclusive_price_info': None,
#     'bundle_deal_id': 0,
#     'can_use_bundle_deal': False,
#     'bundle_deal_info': None,
#     'is_group_buy_item': None,
#     'has_group_buy_stock': None,
#     'group_buy_info': None,
#     'welcome_package_type': 0,
#     'welcome_package_info': None,
#     'add_on_deal_info': None,
#     'can_use_wholesale': False,
#     'is_preferred_plus_seller': False,
#     'shop_location': 'KOTA TANGERANG',
#     'has_model_with_available_shopee_stock': False,
#     'voucher_info': None,
#     'can_use_cod': False,
#     'is_on_flash_sale': False,
#     'spl_installment_tenure': None,
#     'is_live_streaming_price': None,
#     'is_mart': False,
#     'pack_size': None,
#     'deep_discount_skin': None},
#    'adsid': None,
#    'campaignid': None,
#    'distance': None,
#    'match_type': None,
#    'ads_keyword': None,
#    'deduction_info': None,
#    'collection_id': 1028154,
#    'display_name': '',
#    'campaign_stock': 0,
#    'json_data': None,
#    'tracking_info': None,
#    'itemid': 12570400933,
#    'shopid': 194992662,
#    'algo_image': None,
#    'fe_flags': None,
#    'item_type': 1,
#    'foody_item': None,
#    'search_item_tracking': '{"is_ads":false,"groupid":0,"fe_flags":"{}","item_type":1,"biz_json":"","merge_rank":0,"shuffle_rank":0}',
#    'bff_item_tracking': '{"label_ids":[1000167,1000895,1001176,1001346,1001350,1001657,1001620,1001627,1001642,1002688,1005617,1003454,1005775,1003455,1002164,1006732,1006735,1006761,1011688,1011703,1011707,1011693,1011995,1011962,1012445,1012436,1011689,1011691,1011705,1011993,1012616,1012619,1012746,1000031,1012435,1011712,1011718,1011752,1012446],"is_on_flash_sale":false,"is_liked":false,"with_video":false,"is_dp_mirror_sku":false,"image_position":null}',
#    'personalized_labels': None,
#    'biz_json': None},
#   {'item_basic': {'itemid': 121456177,
#     'shopid': 1521932,
#     'name': 'Beng Beng Chocolate Crisp Wafer - Netto 20 bks x 22 gr',
#     'label_ids': [1,
#      13,
#      36,
#      28,
#      43,
#      47,
#      10,
#      57,
#      1000167,
#      1000198,
#      1000211,
#      1000255,
#      1000260,
#      1000510,
#      1000544,
#      1000550,
#      1000559,
#      1000560,
#      1000653,
#      1001657,
#      1001620,
#      1001627,
#      1001642,
#      1002347,
#      1002363,
#      1002538,
#      1002503,
#      1002688,
#      1002958,
#      1003880,
#      1001175,
#      1005413,
#      1005617,
#      1003454,
#      1005775,
#      1005896,
#      1006131,
#      1006309,
#      1006220,
#      1006257,
#      1006233,
#      1006314,
#      1006318,
#      1006219,
#      1006456,
#      1006732,
#      1006735,
#      1006761,
#      1008694,
#      1008697,
#      1008712,
#      1009084,
#      1009617,
#      1009620,
#      1009637,
#      1010408,
#      1010300,
#      1011707,
#      1011587,
#      1011598,
#      1012296,
#      1012316,
#      1012616,
#      1012619,
#      1000007,
#      1000009,
#      1000124,
#      1000245,
#      1000287,
#      1000340,
#      1000375,
#      1000492,
#      1000494,
#      1000530,
#      1000629,
#      1000630,
#      1000655,
#      1000765,
#      1001025,
#      12,
#      21,
#      25,
#      26,
#      35,
#      44,
#      46,
#      68,
#      69,
#      72,
#      74,
#      1001372,
#      1001381,
#      1001658,
#      1002527,
#      1002504,
#      1002953,
#      1003097,
#      1003455,
#      1004141,
#      1004683,
#      1004829,
#      1004832,
#      1006362,
#      1006214,
#      1006216,
#      1006211,
#      1006208,
#      1007523,
#      1008480,
#      1008041,
#      1008870,
#      1008735,
#      1009454,
#      1010192,
#      1008727,
#      1010409,
#      1009660,
#      1010928,
#      1009652,
#      1011592,
#      1011588,
#      1011718,
#      1012050,
#      1011752,
#      1012294,
#      1012446,
#      1012304,
#      1012791,
#      1000006,
#      1000031],
#     'image': 'ea4bd0bb6720990efd8a657babad1bb3',
#     'images': ['ea4bd0bb6720990efd8a657babad1bb3'],
#     'currency': 'IDR',
#     'stock': 324,
#     'status': 1,
#     'ctime': 1483978782,
#     'sold': 527,
#     'historical_sold': 21181,
#     'liked': False,
#     'liked_count': 7630,
#     'view_count': 10982,
#     'catid': 100629,
#     'brand': 'Tidak Ada Merek',
#     'cmt_count': 9977,
#     'flag': 196610,
#     'cb_option': 0,
#     'item_status': 'normal',
#     'price': 2780000000,
#     'price_min': 2780000000,
#     'price_max': 2780000000,
#     'price_min_before_discount': 3000000000,
#     'price_max_before_discount': 3000000000,
#     'hidden_price_display': None,
#     'price_before_discount': 3000000000,
#     'has_lowest_price_guarantee': True,
#     'show_discount': 7,
#     'raw_discount': 7,
#     'discount': '7%',
#     'is_category_failed': False,
#     'size_chart': None,
#     'video_info_list': None,
#     'tier_variations': [{'name': '',
#       'options': [''],
#       'images': None,
#       'properties': [],
#       'type': 0}],
#     'item_rating': {'rating_star': 4.877045066746963,
#      'rating_count': [9966, 50, 26, 112, 725, 9053],
#      'rcount_with_context': 3599,
#      'rcount_with_image': 3020},
#     'item_type': 0,
#     'reference_item_id': '',
#     'transparent_background_image': '312ae0e55b0bdcc3f75a0a7b3e8a9a49',
#     'is_adult': False,
#     'badge_icon_type': 0,
#     'shopee_verified': True,
#     'is_official_shop': False,
#     'show_official_shop_label': False,
#     'show_shopee_verified_label': True,
#     'show_official_shop_label_in_title': False,
#     'is_cc_installment_payment_eligible': False,
#     'is_non_cc_installment_payment_eligible': False,
#     'coin_earn_label': None,
#     'show_free_shipping': True,
#     'preview_info': None,
#     'coin_info': None,
#     'exclusive_price_info': None,
#     'bundle_deal_id': 0,
#     'can_use_bundle_deal': False,
#     'bundle_deal_info': None,
#     'is_group_buy_item': None,
#     'has_group_buy_stock': None,
#     'group_buy_info': None,
#     'welcome_package_type': 0,
#     'welcome_package_info': None,
#     'add_on_deal_info': {'add_on_deal_id': 6523963,
#      'add_on_deal_label': 'Hadiah Gratis',
#      'sub_type': 1,
#      'status': 1},
#     'can_use_wholesale': False,
#     'is_preferred_plus_seller': False,
#     'shop_location': 'KOTA BANDUNG',
#     'has_model_with_available_shopee_stock': False,
#     'voucher_info': None,
#     'can_use_cod': True,
#     'is_on_flash_sale': False,
#     'spl_installment_tenure': None,
#     'is_live_streaming_price': None,
#     'is_mart': False,
#     'pack_size': None,
#     'deep_discount_skin': None},
#    'adsid': None,
#    'campaignid': None,
#    'distance': None,
#    'match_type': None,
#    'ads_keyword': None,
#    'deduction_info': None,
#    'collection_id': 1028154,
#    'display_name': '',
#    'campaign_stock': 0,
#    'json_data': None,
#    'tracking_info': None,
#    'itemid': 121456177,
#    'shopid': 1521932,
#    'algo_image': None,
#    'fe_flags': None,
#    'item_type': 1,
#    'foody_item': None,
#    'search_item_tracking': '{"is_ads":false,"groupid":0,"fe_flags":"{}","item_type":1,"biz_json":"","merge_rank":0,"shuffle_rank":0}',
#    'bff_item_tracking': '{"label_ids":[1,13,36,28,43,47,10,57,1000167,1000198,1000211,1000255,1000260,1000510,1000544,1000550,1000559,1000560,1000653,1001657,1001620,1001627,1001642,1002347,1002363,1002538,1002503,1002688,1002958,1003880,1001175,1005413,1005617,1003454,1005775,1005896,1006131,1006309,1006220,1006257,1006233,1006314,1006318,1006219,1006456,1006732,1006735,1006761,1008694,1008697,1008712,1009084,1009617,1009620,1009637,1010408,1010300,1011707,1011587,1011598,1012296,1012316,1012616,1012619,1000007,1000009,1000124,1000245,1000287,1000340,1000375,1000492,1000494,1000530,1000629,1000630,1000655,1000765,1001025,12,21,25,26,35,44,46,68,69,72,74,1001372,1001381,1001658,1002527,1002504,1002953,1003097,1003455,1004141,1004683,1004829,1004832,1006362,1006214,1006216,1006211,1006208,1007523,1008480,1008041,1008870,1008735,1009454,1010192,1008727,1010409,1009660,1010928,1009652,1011592,1011588,1011718,1012050,1011752,1012294,1012446,1012304,1012791,1000006,1000031],"is_on_flash_sale":false,"is_liked":false,"with_video":false,"is_dp_mirror_sku":false,"image_position":null}',
#    'personalized_labels': None,
#    'biz_json': None},
#   {'item_basic': {'itemid': 884658629,
#     'shopid': 392752,
#     'name': 'Silver Queen Rockr 22 gr',
#     'label_ids': [1,
#      13,
#      28,
#      43,
#      47,
#      10,
#      1000167,
#      1000198,
#      1000211,
#      1000255,
#      1000544,
#      1000550,
#      1000559,
#      1000560,
#      1000653,
#      1001657,
#      1002538,
#      1002503,
#      1002688,
#      1002958,
#      1003715,
#      1003880,
#      1001175,
#      1006314,
#      1006220,
#      1006732,
#      1006735,
#      1006761,
#      1007598,
#      1007970,
#      1011732,
#      1011738,
#      1012003,
#      1011707,
#      1012296,
#      1012316,
#      1012616,
#      1012619,
#      1000006,
#      1000009,
#      1000124,
#      1000245,
#      1000340,
#      1000375,
#      1000492,
#      1000494,
#      1000629,
#      1000630,
#      1001025,
#      12,
#      21,
#      25,
#      26,
#      35,
#      44,
#      46,
#      69,
#      71,
#      72,
#      74,
#      1001658,
#      1002164,
#      1002692,
#      1002959,
#      1003211,
#      1004141,
#      1000260,
#      1004424,
#      1004684,
#      1000287,
#      1009126,
#      1003033,
#      1010409,
#      1011592,
#      1011588,
#      1012791,
#      1007092],
#     'image': '616f0d63ba5929822fe6e4d08810865b',
#     'images': ['616f0d63ba5929822fe6e4d08810865b'],
#     'currency': 'IDR',
#     'stock': 147,
#     'status': 1,
#     'ctime': 1517446649,
#     'sold': 225,
#     'historical_sold': 10905,
#     'liked': False,
#     'liked_count': 1834,
#     'view_count': 3355,
#     'catid': 100629,
#     'brand': 'Silver Queen',
#     'cmt_count': 2294,
#     'flag': 131074,
#     'cb_option': 0,
#     'item_status': 'normal',
#     'price': 400000000,
#     'price_min': 400000000,
#     'price_max': 400000000,
#     'price_min_before_discount': 550000000,
#     'price_max_before_discount': 550000000,
#     'hidden_price_display': None,
#     'price_before_discount': 550000000,
#     'has_lowest_price_guarantee': True,
#     'show_discount': 27,
#     'raw_discount': 27,
#     'discount': '27%',
#     'is_category_failed': False,
#     'size_chart': None,
#     'video_info_list': None,
#     'tier_variations': [{'name': 'Variasi',
#       'options': ['Chocolate', 'Dark Chocolate'],
#       'images': None,
#       'properties': [],
#       'type': 0}],
#     'item_rating': {'rating_star': 4.929380993897123,
#      'rating_count': [2294, 1, 2, 14, 124, 2153],
#      'rcount_with_context': 903,
#      'rcount_with_image': 877},
#     'item_type': 0,
#     'reference_item_id': '',
#     'transparent_background_image': '2ccf2ce46a7ff4e745c90df191219bd3',
#     'is_adult': False,
#     'badge_icon_type': 0,
#     'shopee_verified': True,
#     'is_official_shop': False,
#     'show_official_shop_label': False,
#     'show_shopee_verified_label': True,
#     'show_official_shop_label_in_title': False,
#     'is_cc_installment_payment_eligible': False,
#     'is_non_cc_installment_payment_eligible': False,
#     'coin_earn_label': None,
#     'show_free_shipping': True,
#     'preview_info': None,
#     'coin_info': None,
#     'exclusive_price_info': None,
#     'bundle_deal_id': 0,
#     'can_use_bundle_deal': False,
#     'bundle_deal_info': None,
#     'is_group_buy_item': None,
#     'has_group_buy_stock': None,
#     'group_buy_info': None,
#     'welcome_package_type': 0,
#     'welcome_package_info': None,
#     'add_on_deal_info': None,
#     'can_use_wholesale': False,
#     'is_preferred_plus_seller': True,
#     'shop_location': 'KOTA BANDUNG',
#     'has_model_with_available_shopee_stock': False,
#     'voucher_info': None,
#     'can_use_cod': False,
#     'is_on_flash_sale': False,
#     'spl_installment_tenure': None,
#     'is_live_streaming_price': None,
#     'is_mart': False,
#     'pack_size': None,
#     'deep_discount_skin': None},
#    'adsid': None,
#    'campaignid': None,
#    'distance': None,
#    'match_type': None,
#    'ads_keyword': None,
#    'deduction_info': None,
#    'collection_id': 1028154,
#    'display_name': '',
#    'campaign_stock': 0,
#    'json_data': None,
#    'tracking_info': None,
#    'itemid': 884658629,
#    'shopid': 392752,
#    'algo_image': None,
#    'fe_flags': None,
#    'item_type': 1,
#    'foody_item': None,
#    'search_item_tracking': '{"is_ads":false,"groupid":0,"fe_flags":"{}","item_type":1,"biz_json":"","merge_rank":0,"shuffle_rank":0}',
#    'bff_item_tracking': '{"label_ids":[1,13,28,43,47,10,1000167,1000198,1000211,1000255,1000544,1000550,1000559,1000560,1000653,1001657,1002538,1002503,1002688,1002958,1003715,1003880,1001175,1006314,1006220,1006732,1006735,1006761,1007598,1007970,1011732,1011738,1012003,1011707,1012296,1012316,1012616,1012619,1000006,1000009,1000124,1000245,1000340,1000375,1000492,1000494,1000629,1000630,1001025,12,21,25,26,35,44,46,69,71,72,74,1001658,1002164,1002692,1002959,1003211,1004141,1000260,1004424,1004684,1000287,1009126,1003033,1010409,1011592,1011588,1012791,1007092],"is_on_flash_sale":false,"is_liked":false,"with_video":false,"is_dp_mirror_sku":false,"image_position":null}',
#    'personalized_labels': None,
#    'biz_json': None},
#   {'item_basic': {'itemid': 6234078253,
#     'shopid': 194992662,
#     'name': 'WoCA Coklat Kopi Luwak Chocolate Bar Premium Dark or Milk',
#     'label_ids': [1000167,
#      1000895,
#      1001176,
#      1001346,
#      1001350,
#      1001657,
#      1001620,
#      1001627,
#      1001642,
#      1002688,
#      1005617,
#      1003454,
#      1005775,
#      1003455,
#      1002164,
#      1006732,
#      1006735,
#      1006761,
#      1011688,
#      1011703,
#      1011707,
#      1011693,
#      1011995,
#      1011962,
#      1012445,
#      1012436,
#      1011689,
#      1011691,
#      1011705,
#      1011993,
#      1012616,
#      1012619,
#      1012746,
#      1000031,
#      1000260,
#      1000593,
#      1000630,
#      1000902,
#      1001177,
#      35,
#      1001372,
#      1001381,
#      1001658,
#      1000569,
#      1003211,
#      1004684,
#      1004682,
#      1011443,
#      1011125,
#      1011592,
#      1011588,
#      1012446],
#     'image': '329bd232f263ee0bdf6ce57e8082bd45',
#     'images': ['329bd232f263ee0bdf6ce57e8082bd45',
#      '5ff88565242777105f0ce8fa7a2d64a0',
#      '505ceb558ce233bfb14e384b733b530e',
#      '159aa9352e3d16792a1b1b5db079b10d'],
#     'currency': 'IDR',
#     'stock': 37914,
#     'status': 1,
#     'ctime': 1589568031,
#     'sold': 236,
#     'historical_sold': 3551,
#     'liked': False,
#     'liked_count': 1138,
#     'view_count': 9431,
#     'catid': 100629,
#     'brand': 'Woca',
#     'cmt_count': 1175,
#     'flag': 196608,
#     'cb_option': 0,
#     'item_status': 'normal',
#     'price': 1599900000,
#     'price_min': 1599900000,
#     'price_max': 2999900000,
#     'price_min_before_discount': 6000000000,
#     'price_max_before_discount': 12000000000,
#     'hidden_price_display': None,
#     'price_before_discount': 6000000000,
#     'has_lowest_price_guarantee': False,
#     'show_discount': 75,
#     'raw_discount': 75,
#     'discount': '75%',
#     'is_category_failed': False,
#     'size_chart': None,
#     'video_info_list': None,
#     'tier_variations': [{'name': 'Berat Bersih',
#       'options': ['40 gram', '90 gram'],
#       'images': None,
#       'properties': [],
#       'type': 0},
#      {'name': 'Jenis Cokelat',
#       'options': ['Milk chocolate', 'Dark chocolate'],
#       'images': None,
#       'properties': [],
#       'type': 0}],
#     'item_rating': {'rating_star': 4.885106382978724,
#      'rating_count': [1176, 1, 5, 18, 80, 1072],
#      'rcount_with_context': 494,
#      'rcount_with_image': 450},
#     'item_type': 0,
#     'reference_item_id': '',
#     'transparent_background_image': '04d42ec4c2c822ee40dbf6c663e4e48d',
#     'is_adult': False,
#     'badge_icon_type': 0,
#     'shopee_verified': False,
#     'is_official_shop': True,
#     'show_official_shop_label': True,
#     'show_shopee_verified_label': False,
#     'show_official_shop_label_in_title': True,
#     'is_cc_installment_payment_eligible': False,
#     'is_non_cc_installment_payment_eligible': False,
#     'coin_earn_label': None,
#     'show_free_shipping': False,
#     'preview_info': None,
#     'coin_info': None,
#     'exclusive_price_info': None,
#     'bundle_deal_id': 0,
#     'can_use_bundle_deal': False,
#     'bundle_deal_info': None,
#     'is_group_buy_item': None,
#     'has_group_buy_stock': None,
#     'group_buy_info': None,
#     'welcome_package_type': 0,
#     'welcome_package_info': None,
#     'add_on_deal_info': None,
#     'can_use_wholesale': False,
#     'is_preferred_plus_seller': False,
#     'shop_location': 'KOTA TANGERANG',
#     'has_model_with_available_shopee_stock': False,
#     'voucher_info': None,
#     'can_use_cod': True,
#     'is_on_flash_sale': False,
#     'spl_installment_tenure': None,
#     'is_live_streaming_price': None,
#     'is_mart': False,
#     'pack_size': None,
#     'deep_discount_skin': None},
#    'adsid': None,
#    'campaignid': None,
#    'distance': None,
#    'match_type': None,
#    'ads_keyword': None,
#    'deduction_info': None,
#    'collection_id': 1028154,
#    'display_name': '',
#    'campaign_stock': 0,
#    'json_data': None,
#    'tracking_info': None,
#    'itemid': 6234078253,
#    'shopid': 194992662,
#    'algo_image': None,
#    'fe_flags': None,
#    'item_type': 1,
#    'foody_item': None,
#    'search_item_tracking': '{"is_ads":false,"groupid":0,"fe_flags":"{}","item_type":1,"biz_json":"","merge_rank":0,"shuffle_rank":0}',
#    'bff_item_tracking': '{"label_ids":[1000167,1000895,1001176,1001346,1001350,1001657,1001620,1001627,1001642,1002688,1005617,1003454,1005775,1003455,1002164,1006732,1006735,1006761,1011688,1011703,1011707,1011693,1011995,1011962,1012445,1012436,1011689,1011691,1011705,1011993,1012616,1012619,1012746,1000031,1000260,1000593,1000630,1000902,1001177,35,1001372,1001381,1001658,1000569,1003211,1004684,1004682,1011443,1011125,1011592,1011588,1012446],"is_on_flash_sale":false,"is_liked":false,"with_video":false,"is_dp_mirror_sku":false,"image_position":null}',
#    'personalized_labels': None,
#    'biz_json': None},
#   {'item_basic': {'itemid': 1545698853,
#     'shopid': 20458255,
#     'name': 'Gery Meiseis 7 gr x10',
#     'label_ids': [1,
#      14,
#      27,
#      37,
#      28,
#      43,
#      10,
#      48,
#      58,
#      1000109,
#      1000167,
#      1000197,
#      1000230,
#      1000381,
#      1000260,
#      1000528,
#      1000529,
#      1000544,
#      1000549,
#      1000653,
#      1001227,
#      1001334,
#      1001325,
#      1001669,
#      1001657,
#      1001949,
#      1001619,
#      1001624,
#      1001643,
#      1002033,
#      1002471,
#      1002346,
#      1002355,
#      1002640,
#      1002642,
#      1002515,
#      1002502,
#      1002689,
#      1002726,
#      1002754,
#      1000246,
#      1002164,
#      1003454,
#      1003518,
#      1003767,
#      1003689,
#      1003830,
#      1000044,
#      1004388,
#      1004378,
#      1004491,
#      1004498,
#      1006049,
#      1006056,
#      1006057,
#      1006090,
#      1006066,
#      1006067,
#      1006221,
#      1006257,
#      1006232,
#      1006313,
#      1006317,
#      1006217,
#      1006732,
#      1006945,
#      1007186,
#      1008208,
#      1009623,
#      1009626,
#      1009648,
#      1010299,
#      1010300,
#      1011126,
#      1011188,
#      1011431,
#      1011688,
#      1011703,
#      1011707,
#      1011611,
#      1011693,
#      1011608,
#      1011995,
#      1011962,
#      1012445,
#      1012436,
#      1012277,
#      1012533,
#      1012310,
#      1012616,
#      1012619,
#      1012746,
#      1012871,
#      1012874,
#      1012882,
#      1000006,
#      1000031,
#      1000055,
#      1000129,
#      1000245,
#      1000340,
#      1000375,
#      1000380,
#      1000492,
#      1000494,
#      1000515,
#      1000535,
#      1000545,
#      1000629,
#      1000630,
#      1000647,
#      1000655,
#      1000754,
#      1000755,
#      1000765,
#      12,
#      20,
#      25,
#      32,
#      34,
#      35,
#      1001372,
#      1001381,
#      1001596,
#      1001658,
#      1001797,
#      1002081,
#      1002080,
#      1001901,
#      1000579,
#      1002504,
#      1002474,
#      1002692,
#      1001037,
#      1000247,
#      1003278,
#      1003218,
#      1003954,
#      1004141,
#      1004684,
#      1004682,
#      1001025,
#      1004942,
#      1003455,
#      1006081,
#      1006088,
#      1006089,
#      1006216,
#      1006202,
#      1006205,
#      1006208,
#      1006211,
#      1006472,
#      1008444,
#      1009348,
#      1009533,
#      1009537,
#      1010192,
#      1009660,
#      1011130,
#      1009454,
#      1010928,
#      1009652,
#      1011718,
#      1012050,
#      1011747,
#      1011751,
#      1011752,
#      1011712,
#      1012218,
#      1012435,
#      1012446,
#      1012792,
#      1012791,
#      1007093],
#     'image': 'af4582f2199304eb15d6e82483c4c0f6',
#     'images': ['af4582f2199304eb15d6e82483c4c0f6',
#      'fcba00810198e82ea06e612c31f7ab91',
#      'd775684ffd99e4d677d3660c14964af0'],
#     'currency': 'IDR',
#     'stock': 1869,
#     'status': 1,
#     'ctime': 1538567432,
#     'sold': 149,
#     'historical_sold': 9731,
#     'liked': False,
#     'liked_count': 919,
#     'view_count': 2113,
#     'catid': 100629,
#     'brand': '0',
#     'cmt_count': 4151,
#     'flag': 302186498,
#     'cb_option': 0,
#     'item_status': 'normal',
#     'price': 510000000,
#     'price_min': 510000000,
#     'price_max': 510000000,
#     'price_min_before_discount': 560000000,
#     'price_max_before_discount': 560000000,
#     'hidden_price_display': None,
#     'price_before_discount': 560000000,
#     'has_lowest_price_guarantee': False,
#     'show_discount': 9,
#     'raw_discount': 9,
#     'discount': '9%',
#     'is_category_failed': False,
#     'size_chart': None,
#     'video_info_list': None,
#     'tier_variations': [{'name': '',
#       'options': [''],
#       'images': None,
#       'properties': [],
#       'type': 0}],
#     'item_rating': {'rating_star': 4.917088455049409,
#      'rating_count': [4151, 12, 5, 28, 232, 3874],
#      'rcount_with_context': 2110,
#      'rcount_with_image': 2067},
#     'item_type': 0,
#     'reference_item_id': '',
#     'transparent_background_image': '4b942cc441581e935bc039e2a6075874',
#     'is_adult': False,
#     'badge_icon_type': 5,
#     'shopee_verified': False,
#     'is_official_shop': True,
#     'show_official_shop_label': True,
#     'show_shopee_verified_label': False,
#     'show_official_shop_label_in_title': True,
#     'is_cc_installment_payment_eligible': False,
#     'is_non_cc_installment_payment_eligible': False,
#     'coin_earn_label': None,
#     'show_free_shipping': True,
#     'preview_info': None,
#     'coin_info': None,
#     'exclusive_price_info': None,
#     'bundle_deal_id': 0,
#     'can_use_bundle_deal': False,
#     'bundle_deal_info': None,
#     'is_group_buy_item': None,
#     'has_group_buy_stock': None,
#     'group_buy_info': None,
#     'welcome_package_type': 0,
#     'welcome_package_info': None,
#     'add_on_deal_info': None,
#     'can_use_wholesale': False,
#     'is_preferred_plus_seller': False,
#     'shop_location': 'KOTA BEKASI',
#     'has_model_with_available_shopee_stock': True,
#     'voucher_info': None,
#     'can_use_cod': True,
#     'is_on_flash_sale': False,
#     'spl_installment_tenure': None,
#     'is_live_streaming_price': None,
#     'is_mart': False,
#     'pack_size': None,
#     'deep_discount_skin': None},
#    'adsid': None,
#    'campaignid': None,
#    'distance': None,
#    'match_type': None,
#    'ads_keyword': None,
#    'deduction_info': None,
#    'collection_id': 1028154,
#    'display_name': '',
#    'campaign_stock': 0,
#    'json_data': None,
#    'tracking_info': None,
#    'itemid': 1545698853,
#    'shopid': 20458255,
#    'algo_image': None,
#    'fe_flags': None,
#    'item_type': 1,
#    'foody_item': None,
#    'search_item_tracking': '{"is_ads":false,"groupid":0,"fe_flags":"{}","item_type":1,"biz_json":"","merge_rank":0,"shuffle_rank":0}',
#    'bff_item_tracking': '{"label_ids":[1,14,27,37,28,43,10,48,58,1000109,1000167,1000197,1000230,1000381,1000260,1000528,1000529,1000544,1000549,1000653,1001227,1001334,1001325,1001669,1001657,1001949,1001619,1001624,1001643,1002033,1002471,1002346,1002355,1002640,1002642,1002515,1002502,1002689,1002726,1002754,1000246,1002164,1003454,1003518,1003767,1003689,1003830,1000044,1004388,1004378,1004491,1004498,1006049,1006056,1006057,1006090,1006066,1006067,1006221,1006257,1006232,1006313,1006317,1006217,1006732,1006945,1007186,1008208,1009623,1009626,1009648,1010299,1010300,1011126,1011188,1011431,1011688,1011703,1011707,1011611,1011693,1011608,1011995,1011962,1012445,1012436,1012277,1012533,1012310,1012616,1012619,1012746,1012871,1012874,1012882,1000006,1000031,1000055,1000129,1000245,1000340,1000375,1000380,1000492,1000494,1000515,1000535,1000545,1000629,1000630,1000647,1000655,1000754,1000755,1000765,12,20,25,32,34,35,1001372,1001381,1001596,1001658,1001797,1002081,1002080,1001901,1000579,1002504,1002474,1002692,1001037,1000247,1003278,1003218,1003954,1004141,1004684,1004682,1001025,1004942,1003455,1006081,1006088,1006089,1006216,1006202,1006205,1006208,1006211,1006472,1008444,1009348,1009533,1009537,1010192,1009660,1011130,1009454,1010928,1009652,1011718,1012050,1011747,1011751,1011752,1011712,1012218,1012435,1012446,1012792,1012791,1007093],"is_on_flash_sale":false,"is_liked":false,"with_video":false,"is_dp_mirror_sku":false,"image_position":null}',
#    'personalized_labels': None,
#    'biz_json': None},
#   {'item_basic': {'itemid': 3294568795,
#     'shopid': 65323877,
#     'name': 'Chocolatos Dark 20 x 16 gr (1 Box)',
#     'label_ids': [1,
#      27,
#      37,
#      28,
#      43,
#      10,
#      48,
#      58,
#      1000072,
#      1000109,
#      1000167,
#      1000197,
#      1000357,
#      1000366,
#      1000369,
#      1000396,
#      1000383,
#      1000386,
#      1000389,
#      1000392,
#      1000381,
#      1000429,
#      1000428,
#      1000416,
#      1000422,
#      1000436,
#      1000439,
#      1000442,
#      1000446,
#      1000449,
#      1000260,
#      1000498,
#      1000501,
#      1000504,
#      1000510,
#      1000511,
#      1000509,
#      1000526,
#      1000528,
#      1000529,
#      1000549,
#      1000246,
#      1000594,
#      1000544,
#      1000579,
#      1001657,
#      1001619,
#      1001624,
#      1001643,
#      1002346,
#      1002355,
#      1002515,
#      1002676,
#      1002502,
#      1002689,
#      1002726,
#      1002164,
#      1003514,
#      1000044,
#      1003954,
#      1004388,
#      1004378,
#      1005617,
#      1003454,
#      1005775,
#      1006257,
#      1006226,
#      1006229,
#      1006246,
#      1006676,
#      1006732,
#      1007332,
#      1007377,
#      1007598,
#      1007970,
#      1011165,
#      1011184,
#      1011187,
#      1011176,
#      1011611,
#      1011608,
#      1011707,
#      1011688,
#      1011693,
#      1011995,
#      1011689,
#      1011690,
#      1011691,
#      1011692,
#      1011694,
#      1011695,
#      1011699,
#      1011700,
#      1011701,
#      1011705,
#      1011704,
#      1011992,
#      1011993,
#      1011994,
#      1012616,
#      1012619,
#      1006729,
#      1000031,
#      1000006,
#      1000247,
#      1006954,
#      1001037,
#      1000741,
#      32,
#      1008480,
#      1008593,
#      1001025,
#      1009533,
#      1009537,
#      1010928,
#      1011443,
#      1011405,
#      1003455,
#      1011592,
#      1011588,
#      1011718,
#      1012050,
#      1011747,
#      1011751,
#      1011752,
#      1011712,
#      1003211,
#      1011745,
#      1011749,
#      1012446,
#      1012218,
#      1012791,
#      1007093],
#     'image': '3445526e44297f825496bd39b1a3c15f',
#     'images': ['3445526e44297f825496bd39b1a3c15f',
#      'fb58679ecc587a1183bcf9c210790273',
#      '9b20694854193402ba6718a2f1c282ef'],
#     'currency': 'IDR',
#     'stock': 8942,
#     'status': 1,
#     'ctime': 1626263005,
#     'sold': 1515,
#     'historical_sold': 10270,
#     'liked': False,
#     'liked_count': 1292,
#     'view_count': 31772,
#     'catid': 100629,
#     'brand': None,
#     'cmt_count': 2993,
#     'flag': 268632064,
#     'cb_option': 0,
#     'item_status': 'normal',
#     'price': 1860000000,
#     'price_min': 1860000000,
#     'price_max': 1860000000,
#     'price_min_before_discount': 2050000000,
#     'price_max_before_discount': 2050000000,
#     'hidden_price_display': None,
#     'price_before_discount': 2050000000,
#     'has_lowest_price_guarantee': False,
#     'show_discount': 9,
#     'raw_discount': 9,
#     'discount': '9%',
#     'is_category_failed': False,
#     'size_chart': None,
#     'video_info_list': None,
#     'tier_variations': [{'name': '',
#       'options': [''],
#       'images': None,
#       'properties': [],
#       'type': 0}],
#     'item_rating': {'rating_star': 4.890969899665552,
#      'rating_count': [2993, 12, 16, 41, 157, 2767],
#      'rcount_with_context': 1322,
#      'rcount_with_image': 1231},
#     'item_type': 0,
#     'reference_item_id': '',
#     'transparent_background_image': '9ce16ed069f8c91fc678247bde4c22df',
#     'is_adult': False,
#     'badge_icon_type': 5,
#     'shopee_verified': False,
#     'is_official_shop': True,
#     'show_official_shop_label': True,
#     'show_shopee_verified_label': False,
#     'show_official_shop_label_in_title': True,
#     'is_cc_installment_payment_eligible': False,
#     'is_non_cc_installment_payment_eligible': False,
#     'coin_earn_label': None,
#     'show_free_shipping': False,
#     'preview_info': None,
#     'coin_info': None,
#     'exclusive_price_info': None,
#     'bundle_deal_id': 0,
#     'can_use_bundle_deal': False,
#     'bundle_deal_info': None,
#     'is_group_buy_item': None,
#     'has_group_buy_stock': None,
#     'group_buy_info': None,
#     'welcome_package_type': 0,
#     'welcome_package_info': None,
#     'add_on_deal_info': {'add_on_deal_id': 6619224,
#      'add_on_deal_label': 'Kombo Hemat',
#      'sub_type': 0,
#      'status': 1},
#     'can_use_wholesale': False,
#     'is_preferred_plus_seller': False,
#     'shop_location': 'KOTA BEKASI',
#     'has_model_with_available_shopee_stock': True,
#     'voucher_info': None,
#     'can_use_cod': True,
#     'is_on_flash_sale': False,
#     'spl_installment_tenure': None,
#     'is_live_streaming_price': None,
#     'is_mart': True,
#     'pack_size': None,
#     'deep_discount_skin': {'skin_id': 0,
#      'start_time': 0,
#      'end_time': 0,
#      'skin_data': {'promo_label': {'promotion_price': 'Rp 10.200',
#        'hidden_promotion_price': 'Rp ?0.200',
#        'text': None,
#        'start_time': 1645851600,
#        'end_time': 1645851660}}}},
#    'adsid': None,
#    'campaignid': None,
#    'distance': None,
#    'match_type': None,
#    'ads_keyword': None,
#    'deduction_info': None,
#    'collection_id': 1028154,
#    'display_name': '',
#    'campaign_stock': 0,
#    'json_data': None,
#    'tracking_info': None,
#    'itemid': 3294568795,
#    'shopid': 65323877,
#    'algo_image': None,
#    'fe_flags': None,
#    'item_type': 1,
#    'foody_item': None,
#    'search_item_tracking': '{"is_ads":false,"groupid":0,"fe_flags":"{}","item_type":1,"biz_json":"","merge_rank":0,"shuffle_rank":0}',
#    'bff_item_tracking': '{"label_ids":[1,27,37,28,43,10,48,58,1000072,1000109,1000167,1000197,1000357,1000366,1000369,1000396,1000383,1000386,1000389,1000392,1000381,1000429,1000428,1000416,1000422,1000436,1000439,1000442,1000446,1000449,1000260,1000498,1000501,1000504,1000510,1000511,1000509,1000526,1000528,1000529,1000549,1000246,1000594,1000544,1000579,1001657,1001619,1001624,1001643,1002346,1002355,1002515,1002676,1002502,1002689,1002726,1002164,1003514,1000044,1003954,1004388,1004378,1005617,1003454,1005775,1006257,1006226,1006229,1006246,1006676,1006732,1007332,1007377,1007598,1007970,1011165,1011184,1011187,1011176,1011611,1011608,1011707,1011688,1011693,1011995,1011689,1011690,1011691,1011692,1011694,1011695,1011699,1011700,1011701,1011705,1011704,1011992,1011993,1011994,1012616,1012619,1006729,1000031,1000006,1000247,1006954,1001037,1000741,32,1008480,1008593,1001025,1009533,1009537,1010928,1011443,1011405,1003455,1011592,1011588,1011718,1012050,1011747,1011751,1011752,1011712,1003211,1011745,1011749,1012446,1012218,1012791,1007093],"is_on_flash_sale":false,"is_liked":false,"with_video":false,"is_dp_mirror_sku":false,"image_position":null}',
#    'personalized_labels': None,
#    'biz_json': None},
#   {'item_basic': {'itemid': 6035103111,
#     'shopid': 194992662,
#     'name': 'WoCA Coklat Original Premium Chocolate 90 gram',
#     'label_ids': [1000167,
#      1000895,
#      1001176,
#      1001346,
#      1001350,
#      1001657,
#      1001620,
#      1001627,
#      1001642,
#      1002688,
#      1005617,
#      1003454,
#      1005775,
#      1003455,
#      1002164,
#      1006732,
#      1006735,
#      1006761,
#      1011688,
#      1011703,
#      1011707,
#      1011693,
#      1011995,
#      1011962,
#      1012445,
#      1012436,
#      1011689,
#      1011691,
#      1011705,
#      1011993,
#      1012616,
#      1012619,
#      1012746,
#      1000031,
#      1000260,
#      1000630,
#      1000902,
#      1001177,
#      35,
#      1001372,
#      1001381,
#      1001658,
#      1000569,
#      1003211,
#      1004684,
#      1004682,
#      1006212,
#      1011443,
#      1011125,
#      1011592,
#      1011588,
#      1011961,
#      1012435,
#      1011718,
#      1011752,
#      1012446,
#      1011712,
#      1012050],
#     'image': '6ddd02517fd2c429cf763144246f7637',
#     'images': ['6ddd02517fd2c429cf763144246f7637',
#      '047b2737e8a860879438e8cf65444f31',
#      '73605d0f8d50a917d26eb6890746046a',
#      '5f579a1ebf12231b443c30b7078b79cc'],
#     'currency': 'IDR',
#     'stock': 8322,
#     'status': 1,
#     'ctime': 1590327464,
#     'sold': 247,
#     'historical_sold': 4593,
#     'liked': False,
#     'liked_count': 3869,
#     'view_count': 5935,
#     'catid': 100629,
#     'brand': 'Woca',
#     'cmt_count': 1739,
#     'flag': 196608,
#     'cb_option': 0,
#     'item_status': 'normal',
#     'price': 2199900000,
#     'price_min': 2199900000,
#     'price_max': 2199900000,
#     'price_min_before_discount': 4000000000,
#     'price_max_before_discount': 4000000000,
#     'hidden_price_display': None,
#     'price_before_discount': 4000000000,
#     'has_lowest_price_guarantee': True,
#     'show_discount': 45,
#     'raw_discount': 45,
#     'discount': '45%',
#     'is_category_failed': False,
#     'size_chart': None,
#     'video_info_list': None,
#     'tier_variations': [{'name': 'Varian',
#       'options': ['90 gram'],
#       'images': None,
#       'properties': [],
#       'type': 0}],
#     'item_rating': {'rating_star': 4.875719217491369,
#      'rating_count': [1739, 1, 6, 22, 150, 1560],
#      'rcount_with_context': 675,
#      'rcount_with_image': 600},
#     'item_type': 0,
#     'reference_item_id': '',
#     'transparent_background_image': 'dd656ab6404d4673c321b2377103545c',
#     'is_adult': False,
#     'badge_icon_type': 0,
#     'shopee_verified': False,
#     'is_official_shop': True,
#     'show_official_shop_label': True,
#     'show_shopee_verified_label': False,
#     'show_official_shop_label_in_title': True,
#     'is_cc_installment_payment_eligible': False,
#     'is_non_cc_installment_payment_eligible': False,
#     'coin_earn_label': None,
#     'show_free_shipping': False,
#     'preview_info': None,
#     'coin_info': None,
#     'exclusive_price_info': None,
#     'bundle_deal_id': 0,
#     'can_use_bundle_deal': False,
#     'bundle_deal_info': None,
#     'is_group_buy_item': None,
#     'has_group_buy_stock': None,
#     'group_buy_info': None,
#     'welcome_package_type': 0,
#     'welcome_package_info': None,
#     'add_on_deal_info': None,
#     'can_use_wholesale': False,
#     'is_preferred_plus_seller': False,
#     'shop_location': 'KOTA TANGERANG',
#     'has_model_with_available_shopee_stock': False,
#     'voucher_info': None,
#     'can_use_cod': True,
#     'is_on_flash_sale': False,
#     'spl_installment_tenure': None,
#     'is_live_streaming_price': None,
#     'is_mart': False,
#     'pack_size': None,
#     'deep_discount_skin': None},
#    'adsid': None,
#    'campaignid': None,
#    'distance': None,
#    'match_type': None,
#    'ads_keyword': None,
#    'deduction_info': None,
#    'collection_id': 1028154,
#    'display_name': '',
#    'campaign_stock': 0,
#    'json_data': None,
#    'tracking_info': None,
#    'itemid': 6035103111,
#    'shopid': 194992662,
#    'algo_image': None,
#    'fe_flags': None,
#    'item_type': 1,
#    'foody_item': None,
#    'search_item_tracking': '{"is_ads":false,"groupid":0,"fe_flags":"{}","item_type":1,"biz_json":"","merge_rank":0,"shuffle_rank":0}',
#    'bff_item_tracking': '{"label_ids":[1000167,1000895,1001176,1001346,1001350,1001657,1001620,1001627,1001642,1002688,1005617,1003454,1005775,1003455,1002164,1006732,1006735,1006761,1011688,1011703,1011707,1011693,1011995,1011962,1012445,1012436,1011689,1011691,1011705,1011993,1012616,1012619,1012746,1000031,1000260,1000630,1000902,1001177,35,1001372,1001381,1001658,1000569,1003211,1004684,1004682,1006212,1011443,1011125,1011592,1011588,1011961,1012435,1011718,1011752,1012446,1011712,1012050],"is_on_flash_sale":false,"is_liked":false,"with_video":false,"is_dp_mirror_sku":false,"image_position":null}',
#    'personalized_labels': None,
#    'biz_json': None},
#   {'item_basic': {'itemid': 51978211,
#     'shopid': 1521932,
#     'name': 'Choki Choki Chococashew - Netto 20 pcs x 11 gr',
#     'label_ids': [1,
#      13,
#      36,
#      28,
#      43,
#      47,
#      10,
#      57,
#      1000167,
#      1000198,
#      1000211,
#      1000255,
#      1000260,
#      1000510,
#      1000544,
#      1000550,
#      1000559,
#      1000560,
#      1000653,
#      1001657,
#      1001620,
#      1001627,
#      1001642,
#      1002347,
#      1002363,
#      1002538,
#      1002503,
#      1002688,
#      1002958,
#      1003880,
#      1001175,
#      1005413,
#      1005617,
#      1003454,
#      1005775,
#      1005896,
#      1006131,
#      1006309,
#      1006220,
#      1006257,
#      1006233,
#      1006314,
#      1006318,
#      1006219,
#      1006456,
#      1006732,
#      1006735,
#      1006761,
#      1008694,
#      1008697,
#      1008712,
#      1009084,
#      1009617,
#      1009620,
#      1009637,
#      1010408,
#      1010300,
#      1011707,
#      1011587,
#      1011598,
#      1012296,
#      1012316,
#      1012616,
#      1012619,
#      1000007,
#      1000009,
#      1000031,
#      1000071,
#      1000124,
#      1000245,
#      1000340,
#      1000375,
#      1000409,
#      1000469,
#      1000492,
#      1000494,
#      1000515,
#      1000545,
#      1000593,
#      1000629,
#      1000630,
#      1000655,
#      12,
#      21,
#      25,
#      26,
#      35,
#      44,
#      46,
#      68,
#      69,
#      72,
#      74,
#      1001381,
#      1001658,
#      1001797,
#      1001901,
#      1002527,
#      1002504,
#      1002691,
#      1002694,
#      1002959,
#      1003097,
#      1003455,
#      1000006,
#      1001025,
#      1004141,
#      1003033,
#      1004684,
#      1000287,
#      1006216,
#      1002164,
#      1006211,
#      1008480,
#      1008870,
#      1008735,
#      1010192,
#      1008727,
#      1009660,
#      1009652,
#      1011592,
#      1011588,
#      1011718,
#      1012050,
#      1011749,
#      1011751,
#      1011752,
#      1011712,
#      1012294,
#      1012446,
#      1012304,
#      1012791,
#      1007092],
#     'image': 'ce5870269704bc24cbb745f0d60eb183',
#     'images': ['ce5870269704bc24cbb745f0d60eb183'],
#     'currency': 'IDR',
#     'stock': 185,
#     'status': 1,
#     'ctime': 1470743210,
#     'sold': 258,
#     'historical_sold': 8624,
#     'liked': False,
#     'liked_count': 2738,
#     'view_count': 5596,
#     'catid': 100629,
#     'brand': 'Choki Choki',
#     'cmt_count': 3679,
#     'flag': 196610,
#     'cb_option': 0,
#     'item_status': 'normal',
#     'price': 1750000000,
#     'price_min': 1750000000,
#     'price_max': 1750000000,
#     'price_min_before_discount': 2200000000,
#     'price_max_before_discount': 2200000000,
#     'hidden_price_display': None,
#     'price_before_discount': 2200000000,
#     'has_lowest_price_guarantee': True,
#     'show_discount': 20,
#     'raw_discount': 20,
#     'discount': '20%',
#     'is_category_failed': False,
#     'size_chart': None,
#     'video_info_list': None,
#     'tier_variations': [{'name': '',
#       'options': [''],
#       'images': None,
#       'properties': [],
#       'type': 0}],
#     'item_rating': {'rating_star': 4.885023104104376,
#      'rating_count': [3679, 24, 10, 27, 243, 3375],
#      'rcount_with_context': 1207,
#      'rcount_with_image': 997},
#     'item_type': 0,
#     'reference_item_id': '',
#     'transparent_background_image': '',
#     'is_adult': False,
#     'badge_icon_type': 0,
#     'shopee_verified': True,
#     'is_official_shop': False,
#     'show_official_shop_label': False,
#     'show_shopee_verified_label': True,
#     'show_official_shop_label_in_title': False,
#     'is_cc_installment_payment_eligible': False,
#     'is_non_cc_installment_payment_eligible': False,
#     'coin_earn_label': None,
#     'show_free_shipping': True,
#     'preview_info': None,
#     'coin_info': None,
#     'exclusive_price_info': None,
#     'bundle_deal_id': 0,
#     'can_use_bundle_deal': False,
#     'bundle_deal_info': None,
#     'is_group_buy_item': None,
#     'has_group_buy_stock': None,
#     'group_buy_info': None,
#     'welcome_package_type': 0,
#     'welcome_package_info': None,
#     'add_on_deal_info': {'add_on_deal_id': 6523963,
#      'add_on_deal_label': 'Hadiah Gratis',
#      'sub_type': 1,
#      'status': 1},
#     'can_use_wholesale': False,
#     'is_preferred_plus_seller': False,
#     'shop_location': 'KOTA BANDUNG',
#     'has_model_with_available_shopee_stock': False,
#     'voucher_info': None,
#     'can_use_cod': True,
#     'is_on_flash_sale': False,
#     'spl_installment_tenure': None,
#     'is_live_streaming_price': None,
#     'is_mart': False,
#     'pack_size': None,
#     'deep_discount_skin': None},
#    'adsid': None,
#    'campaignid': None,
#    'distance': None,
#    'match_type': None,
#    'ads_keyword': None,
#    'deduction_info': None,
#    'collection_id': 1028154,
#    'display_name': '',
#    'campaign_stock': 0,
#    'json_data': None,
#    'tracking_info': None,
#    'itemid': 51978211,
#    'shopid': 1521932,
#    'algo_image': None,
#    'fe_flags': None,
#    'item_type': 1,
#    'foody_item': None,
# ...
#     'show_discount': 1,
#     'raw_discount': 1,
#     'discount': '1%',
#     'is_category_failed': False,
#     'size_chart': None,
#     'video_info_list': None,
#     'tier_variations': [{'name': '',
#       'options': [''],
#       'images': None,
#       'properties': [],
#       'type': 0}],
#     'item_rating': {'rating_star': 4.579710144927536,
#      'rating_count': [69, 2, 2, 3, 9, 53],
#      'rcount_with_context': 27,
#      'rcount_with_image': 23},
#     'item_type': 0,
#     'reference_item_id': '',
#     'transparent_background_image': '',
#     'is_adult': False,
#     'badge_icon_type': 5,
#     'shopee_verified': False,
#     'is_official_shop': True,
#     'show_official_shop_label': True,
#     'show_shopee_verified_label': False,
#     'show_official_shop_label_in_title': True,
#     'is_cc_installment_payment_eligible': False,
#     'is_non_cc_installment_payment_eligible': False,
#     'coin_earn_label': None,
#     'show_free_shipping': True,
#     'preview_info': None,
#     'coin_info': None,
#     'exclusive_price_info': None,
#     'bundle_deal_id': 0,
#     'can_use_bundle_deal': False,
#     'bundle_deal_info': None,
#     'is_group_buy_item': None,
#     'has_group_buy_stock': None,
#     'group_buy_info': None,
#     'welcome_package_type': 0,
#     'welcome_package_info': None,
#     'add_on_deal_info': None,
#     'can_use_wholesale': False,
#     'is_preferred_plus_seller': False,
#     'shop_location': 'KOTA BEKASI',
#     'has_model_with_available_shopee_stock': True,
#     'voucher_info': {'promotion_id': 298849529184256,
#      'voucher_code': 'MONDFEB1',
#      'label': 'Diskon Rp10RB'},
#     'can_use_cod': True,
#     'is_on_flash_sale': False,
#     'spl_installment_tenure': None,
#     'is_live_streaming_price': None,
#     'is_mart': False,
#     'pack_size': None,
#     'deep_discount_skin': None},
#    'adsid': None,
#    'campaignid': None,
#    'distance': None,
#    'match_type': None,
#    'ads_keyword': None,
#    'deduction_info': None,
#    'collection_id': 1028154,
#    'display_name': '',
#    'campaign_stock': 0,
#    'json_data': None,
#    'tracking_info': None,
#    'itemid': 6623307907,
#    'shopid': 20090785,
#    'algo_image': None,
#    'fe_flags': None,
#    'item_type': 1,
#    'foody_item': None,
#    'search_item_tracking': '{"is_ads":false,"groupid":0,"fe_flags":"{}","item_type":1,"biz_json":"","merge_rank":0,"shuffle_rank":0}',
#    'bff_item_tracking': '{"label_ids":[1,28,43,10,1000167,1000381,1000260,1000498,1000510,1000544,1000549,1001334,1001350,1001325,1001657,1001915,1001949,1001911,1001619,1001624,1001643,1002346,1002355,1002642,1002515,1002502,1002689,1002754,1002879,1002164,1005896,1006049,1006056,1006057,1006090,1006066,1006067,1006313,1006221,1006732,1006734,1006754,1007332,1007377,1007598,1007970,1008699,1008703,1008723,1009787,1009623,1009626,1009648,1010274,1010299,1010300,1011069,1011432,1011688,1011703,1011707,1011693,1011995,1011962,1012295,1012310,1011691,1011705,1012619,1012746,1012871,1012874,1012882,1000055,1000380,1000492,1000494,1000535,1000647,35,1001381,1002953,1004141,1004684,1006081,1006088,1006089,1008870,1008735,1009533,1009537,1008727,1009660,1010561,1009652,1011712,1011718,1011751,1012446,1012791],"is_on_flash_sale":false,"is_liked":false,"with_video":false,"is_dp_mirror_sku":false,"image_position":null}',
#    'personalized_labels': None,
#    'biz_json': None},
#   {'item_basic': {'itemid': 8379906712,
#     'shopid': 65323877,
#     'name': 'Silverqueen Chunky Bar Almond Cokelat 2 x 95 gr',
#     'label_ids': [1,
#      27,
#      37,
#      28,
#      43,
#      10,
#      48,
#      58,
#      1000072,
#      1000109,
#      1000167,
#      1000197,
#      1000357,
#      1000366,
#      1000369,
#      1000396,
#      1000383,
#      1000386,
#      1000389,
#      1000392,
#      1000381,
#      1000429,
#      1000428,
#      1000416,
#      1000422,
#      1000436,
#      1000439,
#      1000442,
#      1000446,
#      1000449,
#      1000260,
#      1000498,
#      1000501,
#      1000504,
#      1000510,
#      1000511,
#      1000509,
#      1000526,
#      1000528,
#      1000529,
#      1000549,
#      1000246,
#      1000594,
#      1000544,
#      1000579,
#      1001657,
#      1001619,
#      1001624,
#      1001643,
#      1002346,
#      1002355,
#      1002515,
#      1002676,
#      1002502,
#      1002689,
#      1002726,
#      1002164,
#      1003514,
#      1000044,
#      1003954,
#      1004388,
#      1004378,
#      1005617,
#      1003454,
#      1005775,
#      1006257,
#      1006226,
#      1006229,
#      1006246,
#      1006676,
#      1006732,
#      1007332,
#      1007377,
#      1007598,
#      1007970,
#      1011165,
#      1011184,
#      1011187,
#      1011176,
#      1011611,
#      1011608,
#      1011707,
#      1011688,
#      1011693,
#      1011995,
#      1011689,
#      1011690,
#      1011691,
#      1011692,
#      1011694,
#      1011695,
#      1011699,
#      1011700,
#      1011701,
#      1011705,
#      1011704,
#      1011992,
#      1011993,
#      1011994,
#      1012616,
#      1012619,
#      1001037,
#      32,
#      1008593,
#      1001025,
#      1009533,
#      1009537,
#      1011592,
#      1011588,
#      1011718,
#      1012050,
#      1011747,
#      1011751,
#      1011752,
#      1011712,
#      1012446,
#      1012792,
#      1012791],
#     'image': '45e49103fd76b04b714bd5a4ab261126',
#     'images': ['45e49103fd76b04b714bd5a4ab261126',
#      'ca9be0f92d956ae1ea84120ab1cd4f96',
#      '8db86efa2bec7b962b9685d1dcfbe1b7'],
#     'currency': 'IDR',
#     'stock': 238,
#     'status': 1,
#     'ctime': 1626671730,
#     'sold': 53,
#     'historical_sold': 215,
#     'liked': False,
#     'liked_count': 52,
#     'view_count': 1808,
#     'catid': 100629,
#     'brand': None,
#     'cmt_count': 104,
#     'flag': 268568576,
#     'cb_option': 0,
#     'item_status': 'normal',
#     'price': 4050000000,
#     'price_min': 4050000000,
#     'price_max': 4050000000,
#     'price_min_before_discount': 4820000000,
#     'price_max_before_discount': 4820000000,
#     'hidden_price_display': None,
#     'price_before_discount': 4820000000,
#     'has_lowest_price_guarantee': False,
#     'show_discount': 16,
#     'raw_discount': 16,
#     'discount': '16%',
#     'is_category_failed': False,
#     'size_chart': None,
#     'video_info_list': None,
#     'tier_variations': [{'name': 'Variations',
#       'options': ['Twinpack'],
#       'images': None,
#       'properties': [],
#       'type': 0}],
#     'item_rating': {'rating_star': 4.913461538461538,
#      'rating_count': [104, 1, 0, 0, 5, 98],
#      'rcount_with_context': 32,
#      'rcount_with_image': 30},
#     'item_type': 0,
#     'reference_item_id': '',
#     'transparent_background_image': '',
#     'is_adult': False,
#     'badge_icon_type': 5,
#     'shopee_verified': False,
#     'is_official_shop': True,
#     'show_official_shop_label': True,
#     'show_shopee_verified_label': False,
#     'show_official_shop_label_in_title': True,
#     'is_cc_installment_payment_eligible': False,
#     'is_non_cc_installment_payment_eligible': False,
#     'coin_earn_label': None,
#     'show_free_shipping': False,
#     'preview_info': None,
#     'coin_info': None,
#     'exclusive_price_info': None,
#     'bundle_deal_id': 0,
#     'can_use_bundle_deal': False,
#     'bundle_deal_info': None,
#     'is_group_buy_item': None,
#     'has_group_buy_stock': None,
#     'group_buy_info': None,
#     'welcome_package_type': 0,
#     'welcome_package_info': None,
#     'add_on_deal_info': {'add_on_deal_id': 6619224,
#      'add_on_deal_label': 'Kombo Hemat',
#      'sub_type': 0,
#      'status': 1},
#     'can_use_wholesale': False,
#     'is_preferred_plus_seller': False,
#     'shop_location': 'KOTA BEKASI',
#     'has_model_with_available_shopee_stock': True,
#     'voucher_info': None,
#     'can_use_cod': False,
#     'is_on_flash_sale': False,
#     'spl_installment_tenure': None,
#     'is_live_streaming_price': None,
#     'is_mart': True,
#     'pack_size': None,
#     'deep_discount_skin': None},
#    'adsid': None,
#    'campaignid': None,
#    'distance': None,
#    'match_type': None,
#    'ads_keyword': None,
#    'deduction_info': None,
#    'collection_id': 1028154,
#    'display_name': '',
#    'campaign_stock': 0,
#    'json_data': None,
#    'tracking_info': None,
#    'itemid': 8379906712,
#    'shopid': 65323877,
#    'algo_image': None,
#    'fe_flags': None,
#    'item_type': 1,
#    'foody_item': None,
#    'search_item_tracking': '{"is_ads":false,"groupid":0,"fe_flags":"{}","item_type":1,"biz_json":"","merge_rank":0,"shuffle_rank":0}',
#    'bff_item_tracking': '{"label_ids":[1,27,37,28,43,10,48,58,1000072,1000109,1000167,1000197,1000357,1000366,1000369,1000396,1000383,1000386,1000389,1000392,1000381,1000429,1000428,1000416,1000422,1000436,1000439,1000442,1000446,1000449,1000260,1000498,1000501,1000504,1000510,1000511,1000509,1000526,1000528,1000529,1000549,1000246,1000594,1000544,1000579,1001657,1001619,1001624,1001643,1002346,1002355,1002515,1002676,1002502,1002689,1002726,1002164,1003514,1000044,1003954,1004388,1004378,1005617,1003454,1005775,1006257,1006226,1006229,1006246,1006676,1006732,1007332,1007377,1007598,1007970,1011165,1011184,1011187,1011176,1011611,1011608,1011707,1011688,1011693,1011995,1011689,1011690,1011691,1011692,1011694,1011695,1011699,1011700,1011701,1011705,1011704,1011992,1011993,1011994,1012616,1012619,1001037,32,1008593,1001025,1009533,1009537,1011592,1011588,1011718,1012050,1011747,1011751,1011752,1011712,1012446,1012792,1012791],"is_on_flash_sale":false,"is_liked":false,"with_video":false,"is_dp_mirror_sku":false,"image_position":null}',
#    'personalized_labels': None,
#    'biz_json': None},
#   {'item_basic': {'itemid': 7894815220,
#     'shopid': 65323877,
#     'name': 'Oreo Dutch Cocoa Wafer Choco Vanilla 140.4 gr',
#     'label_ids': [1,
#      27,
#      37,
#      28,
#      43,
#      10,
#      48,
#      58,
#      1000072,
#      1000109,
#      1000167,
#      1000197,
#      1000357,
#      1000366,
#      1000369,
#      1000396,
#      1000383,
#      1000386,
#      1000389,
#      1000392,
#      1000381,
#      1000429,
#      1000428,
#      1000416,
#      1000422,
#      1000436,
#      1000439,
#      1000442,
#      1000446,
#      1000449,
#      1000260,
#      1000498,
#      1000501,
#      1000504,
#      1000510,
#      1000511,
#      1000509,
#      1000526,
#      1000528,
#      1000529,
#      1000549,
#      1000246,
#      1000594,
#      1000544,
#      1000579,
#      1001657,
#      1001619,
#      1001624,
#      1001643,
#      1002346,
#      1002355,
#      1002515,
#      1002676,
#      1002502,
#      1002689,
#      1002726,
#      1002164,
#      1003514,
#      1000044,
#      1003954,
#      1004388,
#      1004378,
#      1005617,
#      1003454,
#      1005775,
#      1006257,
#      1006226,
#      1006229,
#      1006246,
#      1006676,
#      1006732,
#      1007332,
#      1007377,
#      1007598,
#      1007970,
#      1011165,
#      1011184,
#      1011187,
#      1011176,
#      1011611,
#      1011608,
#      1011707,
#      1011688,
#      1011693,
#      1011995,
#      1011689,
#      1011690,
#      1011691,
#      1011692,
#      1011694,
#      1011695,
#      1011699,
#      1011700,
#      1011701,
#      1011705,
#      1011704,
#      1011992,
#      1011993,
#      1011994,
#      1012616,
#      1012619,
#      1000031,
#      1000006,
#      1000247,
#      1006954,
#      1001037,
#      32,
#      1008593,
#      1001025,
#      1011592,
#      1011588,
#      1011718,
#      1012050,
#      1011747,
#      1011751,
#      1011752,
#      1011712,
#      1012446,
#      1012792,
#      1012791,
#      1007093],
#     'image': '1d405177e78444aa3b2d695515af7c44',
#     'images': ['1d405177e78444aa3b2d695515af7c44',
#      '9c48e8bcf0fdf7a5f5056fe3bb42f586',
#      'f17fdf41a259c663e1240c55db2a6d0b'],
#     'currency': 'IDR',
#     'stock': 1152,
#     'status': 1,
#     'ctime': 1626507136,
#     'sold': 9,
#     'historical_sold': 158,
#     'liked': False,
#     'liked_count': 14,
#     'view_count': 225,
#     'catid': 100629,
#     'brand': None,
#     'cmt_count': 43,
#     'flag': 268566528,
#     'cb_option': 0,
#     'item_status': 'normal',
#     'price': 690000000,
#     'price_min': 690000000,
#     'price_max': 690000000,
#     'price_min_before_discount': 800000000,
#     'price_max_before_discount': 800000000,
#     'hidden_price_display': None,
#     'price_before_discount': 800000000,
#     'has_lowest_price_guarantee': False,
#     'show_discount': 14,
#     'raw_discount': 14,
#     'discount': '14%',
#     'is_category_failed': False,
#     'size_chart': None,
#     'video_info_list': None,
#     'tier_variations': [{'name': '',
#       'options': [''],
#       'images': None,
#       'properties': [],
#       'type': 0}],
#     'item_rating': {'rating_star': 4.953488372093023,
#      'rating_count': [43, 0, 0, 1, 0, 42],
#      'rcount_with_context': 16,
#      'rcount_with_image': 15},
#     'item_type': 0,
#     'reference_item_id': '',
#     'transparent_background_image': '',
#     'is_adult': False,
#     'badge_icon_type': 5,
#     'shopee_verified': False,
#     'is_official_shop': True,
#     'show_official_shop_label': True,
#     'show_shopee_verified_label': False,
#     'show_official_shop_label_in_title': True,
#     'is_cc_installment_payment_eligible': False,
#     'is_non_cc_installment_payment_eligible': False,
#     'coin_earn_label': None,
#     'show_free_shipping': False,
#     'preview_info': None,
#     'coin_info': None,
#     'exclusive_price_info': None,
#     'bundle_deal_id': 0,
#     'can_use_bundle_deal': False,
#     'bundle_deal_info': None,
#     'is_group_buy_item': None,
#     'has_group_buy_stock': None,
#     'group_buy_info': None,
#     'welcome_package_type': 0,
#     'welcome_package_info': None,
#     'add_on_deal_info': None,
#     'can_use_wholesale': False,
#     'is_preferred_plus_seller': False,
#     'shop_location': 'KOTA BEKASI',
#     'has_model_with_available_shopee_stock': True,
#     'voucher_info': None,
#     'can_use_cod': False,
#     'is_on_flash_sale': False,
#     'spl_installment_tenure': None,
#     'is_live_streaming_price': None,
#     'is_mart': True,
#     'pack_size': None,
#     'deep_discount_skin': None},
#    'adsid': None,
#    'campaignid': None,
#    'distance': None,
#    'match_type': None,
#    'ads_keyword': None,
#    'deduction_info': None,
#    'collection_id': 1028154,
#    'display_name': '',
#    'campaign_stock': 0,
#    'json_data': None,
#    'tracking_info': None,
#    'itemid': 7894815220,
#    'shopid': 65323877,
#    'algo_image': None,
#    'fe_flags': None,
#    'item_type': 1,
#    'foody_item': None,
#    'search_item_tracking': '{"is_ads":false,"groupid":0,"fe_flags":"{}","item_type":1,"biz_json":"","merge_rank":0,"shuffle_rank":0}',
#    'bff_item_tracking': '{"label_ids":[1,27,37,28,43,10,48,58,1000072,1000109,1000167,1000197,1000357,1000366,1000369,1000396,1000383,1000386,1000389,1000392,1000381,1000429,1000428,1000416,1000422,1000436,1000439,1000442,1000446,1000449,1000260,1000498,1000501,1000504,1000510,1000511,1000509,1000526,1000528,1000529,1000549,1000246,1000594,1000544,1000579,1001657,1001619,1001624,1001643,1002346,1002355,1002515,1002676,1002502,1002689,1002726,1002164,1003514,1000044,1003954,1004388,1004378,1005617,1003454,1005775,1006257,1006226,1006229,1006246,1006676,1006732,1007332,1007377,1007598,1007970,1011165,1011184,1011187,1011176,1011611,1011608,1011707,1011688,1011693,1011995,1011689,1011690,1011691,1011692,1011694,1011695,1011699,1011700,1011701,1011705,1011704,1011992,1011993,1011994,1012616,1012619,1000031,1000006,1000247,1006954,1001037,32,1008593,1001025,1011592,1011588,1011718,1012050,1011747,1011751,1011752,1011712,1012446,1012792,1012791,1007093],"is_on_flash_sale":false,"is_liked":false,"with_video":false,"is_dp_mirror_sku":false,"image_position":null}',
#    'personalized_labels': None,
#    'biz_json': None}],
#  'price_adjust': None,
#  'adjust': {'count': None},
#  'total_ads_count': 0,
#  'hint_keywords': None,
#  'show_disclaimer': False,
#  'json_data': '',
#  'query_rewrite': None,
#  'disclaimer_infos': [],
#  'need_next_search': True,
#  'low_result': {'triggered': False,
#   'scenarios': None,
#   'total_organic_count': 0,
#   'pre_lrp_total_organic_count': 0},
#  'autoplay_info': None,
#  'food_item_info': {'total_count': 0},
#  'search_tracking': '{"algorithm":"eyJzZWFyY2giOiIifQ==","low_result":{"triggered":false,"total_organic_count":0,"pre_lrp_total_organic_count":0},"total_ads_count":0,"total_count":94,"request_id":"bff-search_id_sg9_10.168.131.17_{1f8a1b84d84fc3183c50d5c344ebc900:01000165f6b90dc9:000000c185347d20}_k8s-worker-sg9-live-752.shopeemobile.com"}',
#  'search_sessionid': None,
#  'batch_size': 60}

# %%
df = pd.DataFrame(data_shopee)
df.to_csv('nama_produk.csv')
